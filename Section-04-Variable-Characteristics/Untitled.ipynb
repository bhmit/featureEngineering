# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Datasets/titanic.csv")
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375    B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500   C22        S   11    NaN
# 2   2.0000      1      2  113781  151.5500   C22        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500   C22        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500   C22        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df.isnull().mean()
# Out:
# pclass       0.000000
# survived     0.000000
# name         0.000000
# sex          0.000000
# age          0.200917
# sibsp        0.000000
# parch        0.000000
# ticket       0.000000
# fare         0.000764
# cabin        0.774637
# embarked     0.001528
# boat         0.628724
# body         0.907563
# home.dest    0.430863
# dtype: float64

# %%
df['cabin_null'] = np.where(df['cabin'].isnull(),1,0)

# %%
df['cabin_null'].value_counts()
# Out:
# cabin_null
# 1    1014
# 0     295
# Name: count, dtype: int64

# %%
df[['survived', 'cabin_null']].head(100)
# Out:
#     survived  cabin_null
# 0          1           0
# 1          1           0
# 2          0           0
# 3          0           0
# 4          0           0
# ..       ...         ...
# 95         1           0
# 96         0           0
# 97         1           0
# 98         1           0
# 99         1           0
#
# [100 rows x 2 columns]

# %%
df.groupby(['survived'])['cabin_null'].mean()
# Out:
# survived
# 0    0.873918
# 1    0.614000
# Name: cabin_null, dtype: float64

# %%
df['age_null']=np.where(df['age'].isnull(),1,0)
df.groupby(['survived'])['age_null'].mean()
# Out:
# survived
# 0    0.234858
# 1    0.146000
# Name: age_null, dtype: float64

# %%
df['embarked'].value_counts()
# Out:
# embarked
# S    914
# C    270
# Q    123
# Name: count, dtype: int64

# %%
df['embarked'].isnull().sum()
# Out:
# np.int64(2)

# %%
df[df['embarked'].isnull()]
# Out:
#      pclass  survived                                       name     sex  \
# 168       1         1                        Icard, Miss. Amelie  female
# 284       1         1  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#       age  sibsp  parch  ticket  fare cabin embarked boat  body  \
# 168  38.0      0      0  113572  80.0   B28      NaN    6   NaN
# 284  62.0      0      0  113572  80.0   B28      NaN    6   NaN
#
#           home.dest  cabin_null  age_null
# 168             NaN           0         0
# 284  Cincinatti, OH           0         0

# %%
df_lon = pd.read_csv("../Datasets/loan.csv", usecols=['employment', 'time_employed'])
df_lon.head()
# Out:
#      employment time_employed
# 0       Teacher     <=5 years
# 1    Accountant     <=5 years
# 2  Statistician     <=5 years
# 3         Other     <=5 years
# 4    Bus driver      >5 years

# %%
print(df_lon.isnull().sum())
print(df_lon.isnull().mean())
print(len(df_lon))
# Out:
# employment       611
# time_employed    529
# dtype: int64
# employment       0.0611
# time_employed    0.0529
# dtype: float64
# 10000
