# %%
#test pull from vscode

# %%
import pandas as pd
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt

import seaborn as se
# import spicy.stats as stats
import scipy.stats as stats

#loadin the data 
from sklearn.datasets import fetch_california_housing

# %%
california = fetch_california_housing()
df_X = pd.DataFrame(california.data, columns=california.feature_names)

df_Y = pd.DataFrame(california.target, columns=california.target_names)

# %%
df_X.drop(columns=["Latitude", "Longitude"], inplace=True)

# %%
# %matplotlib inline
# %matplotlib auto

# %%
import matplotlib.pyplot as plt
df_X.hist(bins=50, figsize=(8,10))
plt.show()

# %%
ax = df_X.hist(bins=50, figsize=(8,10))
import matplotlib.pyplot as plt
plt.tight_layout()
plt.savefig("histograms.png", dpi=150)
print("Saved → histograms.png")
# Out:
# Saved → histograms.png

# %%
df_X.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population',
#        'AveOccup'],
#       dtype='object')

# %%
df_X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467

# %%
df_X['MedInc_log'] = np.log(df_X['MedInc']) 
df_X['MedInc_xy'] = 1/df_X['MedInc']

# %%
df_X['MedInc_log'].hist()
# Out:
# <Axes: >

# %%
df_X['MedInc_xy'].hist()
# Out:
# <Axes: >

# %%
df_X['MedInc'].hist()
# Out:
# <Axes: >

# %%
df_X["AveRooms_log"] =np.log(df_X["AveRooms"])
df_X["AveRooms_xy"] = 1 / df_X["AveRooms"]

# %%
df_X["AveRooms_log"].hist()
# Out:
# <Axes: >

# %%
df_X["AveRooms_xy"].hist()
# Out:
# <Axes: >

# %%
df_X["AveRooms"].hist()
# Out:
# <Axes: >

# %%
df_X["AveRooms"].plot(kind='box')
# Out:
# <Axes: >

# %%
df_X["AveRooms_xy"].plot(kind='box')
# Out:
# <Axes: >

# %%
df_X["AveRooms_log"].plot(kind='box')
# Out:
# <Axes: >
