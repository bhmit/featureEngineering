# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split

# %%
use_cols = ['Neighborhood', 'Exterior1st', 'Exterior2nd', 'SalePrice']
df = pd.read_csv("../Datasets/myDataset /house-prices-advanced-regression-techniques/houseprice.csv", 
                 usecols=use_cols)

df.columns,df.head()
# Out:
# (Index(['Neighborhood', 'Exterior1st', 'Exterior2nd', 'SalePrice'], dtype='object'),
#    Neighborhood Exterior1st Exterior2nd  SalePrice
#  0      CollgCr     VinylSd     VinylSd     208500
#  1      Veenker     MetalSd     MetalSd     181500
#  2      CollgCr     VinylSd     VinylSd     223500
#  3      Crawfor     Wd Sdng     Wd Shng     140000
#  4      NoRidge     VinylSd     VinylSd     250000)

# %%
df.nunique()
# Out:
# Neighborhood     25
# Exterior1st      15
# Exterior2nd      16
# SalePrice       663
# dtype: int64

# %%
use_cols = ['Neighborhood', 'Exterior1st', 'Exterior2nd']

for col in use_cols:
    print(col)
    print (df[col].nunique())
    # print(f' the featrue ',col,', has names', df[col].unique())
# Out:
# Neighborhood
# 25
# Exterior1st
# 15
# Exterior2nd
# 16

# %%
use_cols = ['Neighborhood', 'Exterior1st', 'Exterior2nd']

for col in use_cols:
    print(f"\nColumn: {col}")
    unique_values = df[col].unique()
    print(f"Unique values: {unique_values}")
    print(f"Number of unique values: {len(unique_values)}")
# Out:
# Column: Neighborhood
# Unique values: ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'NAmes' 'SawyerW' 'IDOTRR'
#  'MeadowV' 'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill'
#  'Blmngtn' 'BrDale' 'SWISU' 'Blueste']
# Number of unique values: 25
#
# Column: Exterior1st
# Unique values: ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
#  'CBlock']
# Number of unique values: 15
#
# Column: Exterior2nd
# Unique values: ['VinylSd' 'MetalSd' 'Wd Shng' 'HdBoard' 'Plywood' 'Wd Sdng' 'CmentBd'
#  'BrkFace' 'Stucco' 'AsbShng' 'Brk Cmn' 'ImStucc' 'AsphShn' 'Stone'
#  'Other' 'CBlock']
# Number of unique values: 16

# %%
cat_cols = ['Neighborhood', 'Exterior1st', 'Exterior2nd']

for col in cat_cols:
    print('variable: ', col, ' number of labels: ', df[col].nunique())

print('total houses: ', len(df))
# Out:
# variable:  Neighborhood  number of labels:  25
# variable:  Exterior1st  number of labels:  15
# variable:  Exterior2nd  number of labels:  16
# total houses:  1460
